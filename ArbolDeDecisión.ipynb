# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosCordova2023/ArbolDeDecision/blob/main/ArbolDeDecisi%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Titanic Kaggle

# %%
import pandas as pd
datos=pd.read_csv("train.csv")

# %%
datos.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
datos.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import seaborn as sb
sb.countplot(x="Survived", data=datos)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sb.countplot(x="Survived", data=datos, hue="Sex")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
datos.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
datos.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sb.displot(x="Age", data=datos)

# %%
datos["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
datos["Age"].mean()
# Out:
# 29.69911764705882

# %%
datos["Age"].fillna(datos["Age"].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
datos["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
datos["Age"]=datos["Age"].fillna(datos["Age"].mean())

# %%
datos["Age"]
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
datos.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
datos=datos.drop(["Cabin"], axis=1)

# %%
datos.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
datos["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
datos=datos.dropna()

# %%
datos.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
datos.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
datos=datos.drop(["Name","PassengerId","Ticket"], axis=1)

# %%
datos.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
pd.get_dummies(datos["Sex"])
# Out:
#      female   male
# 0     False   True
# 1      True  False
# 2      True  False
# 3      True  False
# 4     False   True
# ..      ...    ...
# 886   False   True
# 887    True  False
# 888    True  False
# 889   False   True
# 890   False   True
#
# [889 rows x 2 columns]

# %%
pd.get_dummies(datos["Sex"], drop_first=True)
# Out:
#       male
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# ..     ...
# 886   True
# 887  False
# 888  False
# 889   True
# 890   True
#
# [889 rows x 1 columns]

# %%
dummies_sex11=pd.get_dummies(datos["Sex"], drop_first=True)

# %%
datos.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
datos =datos.join(dummies_sex11)
datos=datos.drop(["Sex"], axis=1)

# %%
datos=datos.drop(["Sex"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-baefcbc573a9> in <cell line: 1>()
# ----> 1 datos=datos.drop(["Sex"], axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4751                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4752             else:
# -> 4753                 new_axis = axis.drop(labels, errors=errors)
#    4754             indexer = axis.get_indexer(new_axis)
#    4755
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6998         if mask.any():
#    6999             if errors != "ignore":
# -> 7000                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001             indexer = indexer[~mask]
#    7002         return self.delete(indexer)
#
# KeyError: "['Sex'] not found in axis"

# %%
datos.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare Embarked   male
# 0         0       3  22.0      1      0   7.2500        S   True
# 1         1       1  38.0      1      0  71.2833        C  False
# 2         1       3  26.0      0      0   7.9250        S  False
# 3         1       1  35.0      1      0  53.1000        S  False
# 4         0       3  35.0      0      0   8.0500        S   True

# %%
sb.countplot(x=("Survived"), data=datos, hue="Embarked")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
dummies_embarked1=pd.get_dummies(datos["Embarked"], drop_first=True)

# %%
datos=datos.join(dummies_embarked1)

# %%
datos=datos.drop(["Embarked"], axis=1)

# %%
datos.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare   male      Q      S
# 0         0       3  22.0      1      0   7.2500   True  False   True
# 1         1       1  38.0      1      0  71.2833  False  False  False
# 2         1       3  26.0      0      0   7.9250  False  False   True
# 3         1       1  35.0      1      0  53.1000  False  False   True
# 4         0       3  35.0      0      0   8.0500   True  False   True

# %%
sb.heatmap(datos.corr(), annot=True,cmap="YlGnBu" )
# Out:
# <Axes: >

# %%
sb.countplot(x="Survived", data=datos, hue="Pclass")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
from re import X
X=datos.drop(["Survived"], axis=1)
y=datos["Survived"]

# %%
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X,y,test_size=.2)

# %%
from sklearn.tree import DecisionTreeClassifier

modelo=DecisionTreeClassifier(max_depth=50)
modelo.fit(X_ent, y_ent)
predicciones=modelo.predict(X_pru)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.7808988764044944

# %%
from sklearn.tree import DecisionTreeClassifier

resultados=[]
for i in range(1,20):
  modelo=DecisionTreeClassifier(max_depth=i)
  modelo.fit(X_ent, y_ent)
  predicciones=modelo.predict(X_pru)
  exactitud=accuracy_score(y_pru, predicciones)
  print(f"Resultado para {i}:{exactitud}")
  resultados.append(exactitud)
# Out:
# Resultado para 1:0.7640449438202247
# Resultado para 2:0.7528089887640449
# Resultado para 3:0.7865168539325843
# Resultado para 4:0.7752808988764045
# Resultado para 5:0.7921348314606742
# Resultado para 6:0.8033707865168539
# Resultado para 7:0.8089887640449438
# Resultado para 8:0.8033707865168539
# Resultado para 9:0.8146067415730337
# Resultado para 10:0.8258426966292135
# Resultado para 11:0.8146067415730337
# Resultado para 12:0.8089887640449438
# Resultado para 13:0.8089887640449438
# Resultado para 14:0.8033707865168539
# Resultado para 15:0.797752808988764
# Resultado para 16:0.797752808988764
# Resultado para 17:0.7865168539325843
# Resultado para 18:0.7865168539325843
# Resultado para 19:0.7808988764044944

# %%
sb.lineplot(data=resultados)
# Out:
# <Axes: >

# %%
modelo=DecisionTreeClassifier(max_depth=10)
modelo.fit(X_ent, y_ent)
predicciones=modelo.predict(X_pru)
exactitud=accuracy_score(y_pru, predicciones)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       112
#            1       0.79      0.73      0.76        66
#
#     accuracy                           0.83       178
#    macro avg       0.82      0.81      0.81       178
# weighted avg       0.82      0.83      0.82       178

# %%
from sklearn.metrics import confusion_matrix
pd.DataFrame(confusion_matrix(y_pru, predicciones), columns=["Pred:No", "Pred:Si"], index=["Real:No", "Real:Si"] )
# Out:
#          Pred:No  Pred:Si
# Real:No       99       13
# Real:Si       18       48

# %%
X_ent.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'male', 'Q', 'S'], dtype='object')

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(100,80))
plot_tree(
    modelo,
    feature_names=X_ent.columns,
    class_names=["Murió","Vivió"],
    filled=True, label="none"
)
# Out:
# [Text(0.4984657622739018, 0.9545454545454546, 'male <= 0.5\n0.474\n711\n[437, 274]\nMurió'),
#  Text(0.2714793281653747, 0.8636363636363636, 'Pclass <= 2.5\n0.371\n248\n[61, 187]\nVivió'),
#  Text(0.15374677002583978, 0.7727272727272727, 'Fare <= 28.856\n0.094\n142\n[7, 135]\nVivió'),
#  Text(0.13178294573643412, 0.6818181818181818, 'Fare <= 28.231\n0.183\n59\n[6, 53]\nVivió'),
#  Text(0.12144702842377261, 0.5909090909090909, 'Age <= 56.0\n0.158\n58\n[5, 53]\nVivió'),
#  Text(0.08785529715762273, 0.5, 'Age <= 27.5\n0.133\n56\n[4, 52]\nVivió'),
#  Text(0.05167958656330749, 0.4090909090909091, 'Age <= 25.5\n0.236\n22\n[3, 19]\nVivió'),
#  Text(0.031007751937984496, 0.3181818181818182, 'Fare <= 13.75\n0.105\n18\n[1, 17]\nVivió'),
#  Text(0.020671834625323, 0.22727272727272727, 'Age <= 21.0\n0.375\n4\n[1, 3]\nVivió'),
#  Text(0.0103359173126615, 0.13636363636363635, '0.0\n2\n[0, 2]\nVivió'),
#  Text(0.031007751937984496, 0.13636363636363635, '0.5\n2\n[1, 1]\nMurió'),
#  Text(0.041343669250646, 0.22727272727272727, '0.0\n14\n[0, 14]\nVivió'),
#  Text(0.07235142118863049, 0.3181818181818182, 'Fare <= 17.429\n0.5\n4\n[2, 2]\nMurió'),
#  Text(0.06201550387596899, 0.22727272727272727, '0.0\n2\n[0, 2]\nVivió'),
#  Text(0.082687338501292, 0.22727272727272727, '0.0\n2\n[2, 0]\nMurió'),
#  Text(0.12403100775193798, 0.4090909090909091, 'Fare <= 13.25\n0.057\n34\n[1, 33]\nVivió'),
#  Text(0.11369509043927649, 0.3181818181818182, 'Age <= 37.0\n0.142\n13\n[1, 12]\nVivió'),
#  Text(0.10335917312661498, 0.22727272727272727, '0.0\n9\n[0, 9]\nVivió'),
#  Text(0.12403100775193798, 0.22727272727272727, 'Age <= 40.0\n0.375\n4\n[1, 3]\nVivió'),
#  Text(0.11369509043927649, 0.13636363636363635, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.1343669250645995, 0.13636363636363635, '0.0\n3\n[0, 3]\nVivió'),
#  Text(0.1343669250645995, 0.3181818181818182, '0.0\n21\n[0, 21]\nVivió'),
#  Text(0.15503875968992248, 0.5, 'Age <= 57.5\n0.5\n2\n[1, 1]\nMurió'),
#  Text(0.14470284237726097, 0.4090909090909091, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.165374677002584, 0.4090909090909091, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.1421188630490956, 0.5909090909090909, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.17571059431524547, 0.6818181818181818, 'Parch <= 1.5\n0.024\n83\n[1, 82]\nVivió'),
#  Text(0.165374677002584, 0.5909090909090909, '0.0\n71\n[0, 71]\nVivió'),
#  Text(0.18604651162790697, 0.5909090909090909, 'Fare <= 135.775\n0.153\n12\n[1, 11]\nVivió'),
#  Text(0.17571059431524547, 0.5, '0.0\n8\n[0, 8]\nVivió'),
#  Text(0.19638242894056848, 0.5, 'Fare <= 158.208\n0.375\n4\n[1, 3]\nVivió'),
#  Text(0.18604651162790697, 0.4090909090909091, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.20671834625322996, 0.4090909090909091, '0.0\n3\n[0, 3]\nVivió'),
#  Text(0.38921188630490955, 0.7727272727272727, 'Fare <= 23.35\n0.5\n106\n[54, 52]\nMurió'),
#  Text(0.3365633074935401, 0.6818181818181818, 'Age <= 36.5\n0.484\n85\n[35, 50]\nVivió'),
#  Text(0.29328165374677, 0.5909090909090909, 'S <= 0.5\n0.467\n78\n[29, 49]\nVivió'),
#  Text(0.23772609819121446, 0.5, 'Fare <= 6.987\n0.382\n35\n[9, 26]\nVivió'),
#  Text(0.22739018087855298, 0.4090909090909091, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.24806201550387597, 0.4090909090909091, 'Age <= 30.85\n0.36\n34\n[8, 26]\nVivió'),
#  Text(0.23772609819121446, 0.3181818181818182, 'Fare <= 15.373\n0.334\n33\n[7, 26]\nVivió'),
#  Text(0.22739018087855298, 0.22727272727272727, 'Fare <= 8.083\n0.403\n25\n[7, 18]\nVivió'),
#  Text(0.20671834625322996, 0.13636363636363635, 'Parch <= 1.0\n0.198\n18\n[2, 16]\nVivió'),
#  Text(0.19638242894056848, 0.045454545454545456, '0.111\n17\n[1, 16]\nVivió'),
#  Text(0.21705426356589147, 0.045454545454545456, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.24806201550387597, 0.13636363636363635, 'Age <= 16.5\n0.408\n7\n[5, 2]\nMurió'),
#  Text(0.23772609819121446, 0.045454545454545456, '0.444\n3\n[1, 2]\nVivió'),
#  Text(0.25839793281653745, 0.045454545454545456, '0.0\n4\n[4, 0]\nMurió'),
#  Text(0.24806201550387597, 0.22727272727272727, '0.0\n8\n[0, 8]\nVivió'),
#  Text(0.25839793281653745, 0.3181818181818182, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.3488372093023256, 0.5, 'Fare <= 20.8\n0.498\n43\n[20, 23]\nVivió'),
#  Text(0.3385012919896641, 0.4090909090909091, 'Parch <= 0.5\n0.489\n40\n[17, 23]\nVivió'),
#  Text(0.3049095607235142, 0.3181818181818182, 'Fare <= 7.713\n0.499\n31\n[16, 15]\nMurió'),
#  Text(0.27906976744186046, 0.22727272727272727, 'Age <= 26.35\n0.32\n5\n[1, 4]\nVivió'),
#  Text(0.268733850129199, 0.13636363636363635, '0.0\n4\n[0, 4]\nVivió'),
#  Text(0.28940568475452194, 0.13636363636363635, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.330749354005168, 0.22727272727272727, 'Fare <= 9.84\n0.488\n26\n[15, 11]\nMurió'),
#  Text(0.31007751937984496, 0.13636363636363635, 'Age <= 25.5\n0.415\n17\n[12, 5]\nMurió'),
#  Text(0.2997416020671835, 0.045454545454545456, '0.198\n9\n[8, 1]\nMurió'),
#  Text(0.32041343669250644, 0.045454545454545456, '0.5\n8\n[4, 4]\nMurió'),
#  Text(0.35142118863049093, 0.13636363636363635, 'Fare <= 17.6\n0.444\n9\n[3, 6]\nVivió'),
#  Text(0.34108527131782945, 0.045454545454545456, '0.245\n7\n[1, 6]\nVivió'),
#  Text(0.36175710594315247, 0.045454545454545456, '0.0\n2\n[2, 0]\nMurió'),
#  Text(0.37209302325581395, 0.3181818181818182, 'Age <= 27.5\n0.198\n9\n[1, 8]\nVivió'),
#  Text(0.36175710594315247, 0.22727272727272727, '0.0\n6\n[0, 6]\nVivió'),
#  Text(0.38242894056847543, 0.22727272727272727, 'Age <= 29.5\n0.444\n3\n[1, 2]\nVivió'),
#  Text(0.37209302325581395, 0.13636363636363635, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.39276485788113696, 0.13636363636363635, '0.0\n2\n[0, 2]\nVivió'),
#  Text(0.35917312661498707, 0.4090909090909091, '0.0\n3\n[3, 0]\nMurió'),
#  Text(0.3798449612403101, 0.5909090909090909, 'Age <= 55.0\n0.245\n7\n[6, 1]\nMurió'),
#  Text(0.3695090439276486, 0.5, '0.0\n6\n[6, 0]\nMurió'),
#  Text(0.39018087855297157, 0.5, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.4418604651162791, 0.6818181818181818, 'Age <= 5.5\n0.172\n21\n[19, 2]\nMurió'),
#  Text(0.42118863049095606, 0.5909090909090909, 'Fare <= 31.331\n0.5\n2\n[1, 1]\nMurió'),
#  Text(0.4108527131782946, 0.5, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.4315245478036176, 0.5, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.4625322997416021, 0.5909090909090909, 'Parch <= 4.5\n0.1\n19\n[18, 1]\nMurió'),
#  Text(0.45219638242894056, 0.5, '0.0\n15\n[15, 0]\nMurió'),
#  Text(0.4728682170542636, 0.5, 'Age <= 38.5\n0.375\n4\n[3, 1]\nMurió'),
#  Text(0.4625322997416021, 0.4090909090909091, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.48320413436692505, 0.4090909090909091, '0.0\n3\n[3, 0]\nMurió'),
#  Text(0.725452196382429, 0.8636363636363636, 'Pclass <= 1.5\n0.305\n463\n[376, 87]\nMurió'),
#  Text(0.6007751937984496, 0.7727272727272727, 'Age <= 28.5\n0.473\n94\n[58, 36]\nMurió'),
#  Text(0.5452196382428941, 0.6818181818181818, 'Fare <= 165.75\n0.465\n19\n[7, 12]\nVivió'),
#  Text(0.5348837209302325, 0.5909090909090909, 'Age <= 24.5\n0.415\n17\n[5, 12]\nVivió'),
#  Text(0.5142118863049095, 0.5, 'Parch <= 0.5\n0.5\n8\n[4, 4]\nMurió'),
#  Text(0.5038759689922481, 0.4090909090909091, '0.0\n3\n[3, 0]\nMurió'),
#  Text(0.524547803617571, 0.4090909090909091, 'Fare <= 79.573\n0.32\n5\n[1, 4]\nVivió'),
#  Text(0.5142118863049095, 0.3181818181818182, 'Age <= 22.0\n0.5\n2\n[1, 1]\nMurió'),
#  Text(0.5038759689922481, 0.22727272727272727, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.524547803617571, 0.22727272727272727, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.5348837209302325, 0.3181818181818182, '0.0\n3\n[0, 3]\nVivió'),
#  Text(0.5555555555555556, 0.5, 'Age <= 27.5\n0.198\n9\n[1, 8]\nVivió'),
#  Text(0.5452196382428941, 0.4090909090909091, '0.0\n6\n[0, 6]\nVivió'),
#  Text(0.5658914728682171, 0.4090909090909091, 'Fare <= 41.3\n0.444\n3\n[1, 2]\nVivió'),
#  Text(0.5555555555555556, 0.3181818181818182, '0.0\n2\n[0, 2]\nVivió'),
#  Text(0.5762273901808785, 0.3181818181818182, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.5555555555555556, 0.5909090909090909, '0.0\n2\n[2, 0]\nMurió'),
#  Text(0.6563307493540051, 0.6818181818181818, 'SibSp <= 0.5\n0.435\n75\n[51, 24]\nMurió'),
#  Text(0.627906976744186, 0.5909090909090909, 'Fare <= 369.927\n0.375\n56\n[42, 14]\nMurió'),
#  Text(0.6175710594315246, 0.5, 'Fare <= 37.0\n0.346\n54\n[42, 12]\nMurió'),
#  Text(0.6072351421188631, 0.4090909090909091, 'Fare <= 25.938\n0.444\n36\n[24, 12]\nMurió'),
#  Text(0.5968992248062015, 0.3181818181818182, '0.0\n7\n[7, 0]\nMurió'),
#  Text(0.6175710594315246, 0.3181818181818182, 'Age <= 53.5\n0.485\n29\n[17, 12]\nMurió'),
#  Text(0.58656330749354, 0.22727272727272727, 'Fare <= 27.135\n0.484\n17\n[7, 10]\nVivió'),
#  Text(0.5762273901808785, 0.13636363636363635, '0.0\n5\n[0, 5]\nVivió'),
#  Text(0.5968992248062015, 0.13636363636363635, 'Fare <= 28.725\n0.486\n12\n[7, 5]\nMurió'),
#  Text(0.58656330749354, 0.045454545454545456, '0.0\n2\n[2, 0]\nMurió'),
#  Text(0.6072351421188631, 0.045454545454545456, '0.5\n10\n[5, 5]\nMurió'),
#  Text(0.648578811369509, 0.22727272727272727, 'Fare <= 35.077\n0.278\n12\n[10, 2]\nMurió'),
#  Text(0.6382428940568475, 0.13636363636363635, 'Age <= 75.5\n0.165\n11\n[10, 1]\nMurió'),
#  Text(0.627906976744186, 0.045454545454545456, '0.0\n10\n[10, 0]\nMurió'),
#  Text(0.648578811369509, 0.045454545454545456, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.6589147286821705, 0.13636363636363635, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.627906976744186, 0.4090909090909091, '0.0\n18\n[18, 0]\nMurió'),
#  Text(0.6382428940568475, 0.5, '0.0\n2\n[0, 2]\nVivió'),
#  Text(0.6847545219638242, 0.5909090909090909, 'Fare <= 113.213\n0.499\n19\n[9, 10]\nVivió'),
#  Text(0.6744186046511628, 0.5, 'Fare <= 52.827\n0.498\n17\n[9, 8]\nMurió'),
#  Text(0.648578811369509, 0.4090909090909091, 'Age <= 34.0\n0.375\n4\n[1, 3]\nVivió'),
#  Text(0.6382428940568475, 0.3181818181818182, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.6589147286821705, 0.3181818181818182, '0.0\n3\n[0, 3]\nVivió'),
#  Text(0.7002583979328165, 0.4090909090909091, 'S <= 0.5\n0.473\n13\n[8, 5]\nMurió'),
#  Text(0.6795865633074936, 0.3181818181818182, 'Fare <= 84.6\n0.48\n5\n[2, 3]\nVivió'),
#  Text(0.6692506459948321, 0.22727272727272727, '0.0\n3\n[0, 3]\nVivió'),
#  Text(0.689922480620155, 0.22727272727272727, '0.0\n2\n[2, 0]\nMurió'),
#  Text(0.7209302325581395, 0.3181818181818182, 'Fare <= 84.425\n0.375\n8\n[6, 2]\nMurió'),
#  Text(0.710594315245478, 0.22727272727272727, 'Age <= 33.5\n0.245\n7\n[6, 1]\nMurió'),
#  Text(0.7002583979328165, 0.13636363636363635, 'Age <= 30.0\n0.5\n2\n[1, 1]\nMurió'),
#  Text(0.689922480620155, 0.045454545454545456, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.710594315245478, 0.045454545454545456, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.7209302325581395, 0.13636363636363635, '0.0\n5\n[5, 0]\nMurió'),
#  Text(0.7312661498708011, 0.22727272727272727, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.6950904392764858, 0.5, '0.0\n2\n[0, 2]\nVivió'),
#  Text(0.8501291989664083, 0.7727272727272727, 'Age <= 9.5\n0.238\n369\n[318, 51]\nMurió'),
#  Text(0.7932816537467701, 0.6818181818181818, 'SibSp <= 2.5\n0.497\n26\n[12, 14]\nVivió'),
#  Text(0.7829457364341085, 0.5909090909090909, '0.0\n13\n[0, 13]\nVivió'),
#  Text(0.8036175710594315, 0.5909090909090909, 'Age <= 3.5\n0.142\n13\n[12, 1]\nMurió'),
#  Text(0.7932816537467701, 0.5, 'Age <= 2.5\n0.278\n6\n[5, 1]\nMurió'),
#  Text(0.7829457364341085, 0.4090909090909091, '0.0\n5\n[5, 0]\nMurió'),
#  Text(0.8036175710594315, 0.4090909090909091, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.813953488372093, 0.5, '0.0\n7\n[7, 0]\nMurió'),
#  Text(0.9069767441860465, 0.6818181818181818, 'Fare <= 15.796\n0.192\n343\n[306, 37]\nMurió'),
#  Text(0.8449612403100775, 0.5909090909090909, 'Age <= 13.5\n0.214\n279\n[245, 34]\nMurió'),
#  Text(0.834625322997416, 0.5, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.8552971576227391, 0.5, 'Fare <= 15.646\n0.209\n278\n[245, 33]\nMurió'),
#  Text(0.8449612403100775, 0.4090909090909091, 'Fare <= 7.91\n0.204\n277\n[245, 32]\nMurió'),
#  Text(0.7829457364341085, 0.3181818181818182, 'Age <= 29.35\n0.16\n137\n[125, 12]\nMurió'),
#  Text(0.751937984496124, 0.22727272727272727, 'Fare <= 3.248\n0.245\n56\n[48, 8]\nMurió'),
#  Text(0.7416020671834626, 0.13636363636363635, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.7622739018087855, 0.13636363636363635, 'S <= 0.5\n0.222\n55\n[48, 7]\nMurió'),
#  Text(0.751937984496124, 0.045454545454545456, '0.444\n9\n[6, 3]\nMurió'),
#  Text(0.772609819121447, 0.045454545454545456, '0.159\n46\n[42, 4]\nMurió'),
#  Text(0.813953488372093, 0.22727272727272727, 'Age <= 32.5\n0.094\n81\n[77, 4]\nMurió'),
#  Text(0.8036175710594315, 0.13636363636363635, 'Age <= 31.5\n0.133\n56\n[52, 4]\nMurió'),
#  Text(0.7932816537467701, 0.045454545454545456, '0.105\n54\n[51, 3]\nMurió'),
#  Text(0.813953488372093, 0.045454545454545456, '0.5\n2\n[1, 1]\nMurió'),
#  Text(0.8242894056847545, 0.13636363636363635, '0.0\n25\n[25, 0]\nMurió'),
#  Text(0.9069767441860465, 0.3181818181818182, 'Fare <= 7.988\n0.245\n140\n[120, 20]\nMurió'),
#  Text(0.8656330749354005, 0.22727272727272727, 'Age <= 29.5\n0.48\n10\n[6, 4]\nMurió'),
#  Text(0.8449612403100775, 0.13636363636363635, 'SibSp <= 0.5\n0.32\n5\n[4, 1]\nMurió'),
#  Text(0.834625322997416, 0.045454545454545456, '0.0\n3\n[3, 0]\nMurió'),
#  Text(0.8552971576227391, 0.045454545454545456, '0.5\n2\n[1, 1]\nMurió'),
#  Text(0.8863049095607235, 0.13636363636363635, 'Age <= 31.5\n0.48\n5\n[2, 3]\nVivió'),
#  Text(0.875968992248062, 0.045454545454545456, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.896640826873385, 0.045454545454545456, '0.5\n4\n[2, 2]\nMurió'),
#  Text(0.9483204134366925, 0.22727272727272727, 'Parch <= 0.5\n0.216\n130\n[114, 16]\nMurió'),
#  Text(0.9276485788113695, 0.13636363636363635, 'Fare <= 13.931\n0.2\n124\n[110, 14]\nMurió'),
#  Text(0.917312661498708, 0.045454545454545456, '0.222\n110\n[96, 14]\nMurió'),
#  Text(0.937984496124031, 0.045454545454545456, '0.0\n14\n[14, 0]\nMurió'),
#  Text(0.9689922480620154, 0.13636363636363635, 'Age <= 31.85\n0.444\n6\n[4, 2]\nMurió'),
#  Text(0.958656330749354, 0.045454545454545456, '0.444\n3\n[1, 2]\nVivió'),
#  Text(0.979328165374677, 0.045454545454545456, '0.0\n3\n[3, 0]\nMurió'),
#  Text(0.8656330749354005, 0.4090909090909091, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.9689922480620154, 0.5909090909090909, 'Fare <= 51.698\n0.089\n64\n[61, 3]\nMurió'),
#  Text(0.958656330749354, 0.5, '0.0\n50\n[50, 0]\nMurió'),
#  Text(0.979328165374677, 0.5, 'Fare <= 63.023\n0.337\n14\n[11, 3]\nMurió'),
#  Text(0.9689922480620154, 0.4090909090909091, 'Age <= 28.85\n0.48\n5\n[2, 3]\nVivió'),
#  Text(0.958656330749354, 0.3181818181818182, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.979328165374677, 0.3181818181818182, 'Age <= 30.85\n0.375\n4\n[1, 3]\nVivió'),
#  Text(0.9689922480620154, 0.22727272727272727, '0.444\n3\n[1, 2]\nVivió'),
#  Text(0.9896640826873385, 0.22727272727272727, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.9896640826873385, 0.4090909090909091, '0.0\n9\n[9, 0]\nMurió')]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.8202247191011236

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       108
#            1       0.81      0.71      0.76        70
#
#     accuracy                           0.82       178
#    macro avg       0.82      0.80      0.81       178
# weighted avg       0.82      0.82      0.82       178

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_pru, predicciones)
# Out:
# array([[96, 12],
#        [20, 50]])

# %%
pd.DataFrame(confusion_matrix(y_pru, predicciones), columns=["Pred:No", "Pred:Si"], index=["Real:No", "Real:Si"] )
# Out:
#          Pred:No  Pred:Si
# Real:No       96       12
# Real:Si       20       50

# %%
X.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare   male      Q      S
# 0       3  22.0      1      0   7.2500   True  False   True
# 1       1  38.0      1      0  71.2833  False  False  False
# 2       3  26.0      0      0   7.9250  False  False   True
# 3       1  35.0      1      0  53.1000  False  False   True
# 4       3  35.0      0      0   8.0500   True  False   True

# %%
nueva_persona=[3,35,0,0,10,1,0,0]
prediccion=modelo.predict([nueva_persona])
if prediccion==1:
  print("Sobreviviste")
else:
  print("No Sobreviviste")
# Out:
# No Sobreviviste
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
nueva_persona=[1,35,0,0,250,1,0,0]
prediccion=modelo.predict([nueva_persona])
if prediccion==1:
  print("Sobreviviste")
else:
  print("No Sobreviviste")
# Out:
# Sobreviviste
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
